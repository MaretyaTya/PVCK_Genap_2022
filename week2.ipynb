# %% [markdown]
# <a href="https://colab.research.google.com/github/MaretyaTya/PVCK_Genap_2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file iamge
#cv.imwrite ('/content/drive/MyDrive/PCVK_MM/Images/mandrilll2.tiff',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype = np.int16)
plt.imshow(black_img)

# %%
#perhatikan boardiant titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow()

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **TUGAS**

# %%
# Red Green
a = img3.copy()

a[:, :, 2] = 0
plt.imshow(a)

# %%
#Blue Green
b = img3.copy()

b[:, :, 0] = 0
plt.imshow(b)

# %%
c = img3.copy()

plt.imshow(c [10:100, 10:100])

# %%
# green, row 5 - 30
d = img3.copy()

d[:, :, 0] = 0
d[:, :, 2] = 0

plt.imshow(d [5:30, :])

# %%
# buat 5 kotak dan warna yang berbeda pada 1 image
import random # memanggil libary random

e = img3.copy()

tinggi = e.shape[0]
lebar = e.shape[1]

for i in range(5):
  r1 = random.randint(0,lebar)
  r2 = random.randint(0,tinggi)
  r3 = random.randint(0,lebar)
  r4 = random.randint(0,tinggi)
  
  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)

  tr = random.randint(5,10)
  cv.rectangle(e, pt1=(r1,r2), pt2=(r3,r4), color=(c1, c2, c3), thickness=tr)

plt.imshow(e)

# %%
f = img3.copy()
f = cv.flip(f,0)

plt.imshow(f)

# %%
# buat 5 kotak dan warna yang berbeda pada 1 image

g = img3.copy()

cv.rectangle(g, pt1=(250,50), pt2=(400,250), color=(255,24,10), thickness=10)
cv.circle(g, center=(345,125), radius=50, color=(100,255,100), thickness=10)
plt.imshow(g)

# %%
# Blue
h = img3.copy()

h[:, :, 0] = 0
h[:, :, 1] = 0

tinggi = h.shape[0]
lebar = h.shape[1]

cv.rectangle(h, pt1=(0,250), pt2=(100,tinggi), color=(255,225,225), thickness=10)

plt.imshow(h)
